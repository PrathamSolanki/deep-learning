# %% [markdown]
# # Practical classes
#
# All exercices will be in Python. It is important that you keep track of exercices and structure you code correctly (e.g. create funcions that you can re-use later)
#
# We will use Jupyter notebooks (formerly known as IPython). You can read the following courses for help:
# * Python and numpy: http://cs231n.github.io/python-numpy-tutorial/
# * Jupyter / IPython : http://cs231n.github.io/ipython-tutorial/
#
# To run this notebook:
# * create a directory somewhere on your filesystem
# * download the .ipynb from the course website: http://teaching.caio-corro.fr/2019-2020/OPT8/
# * move the .ipynb into the directory
# * from a terminal:
#     * cd /directory/path
#     * jupyter notebook
#
# Each group must send me their work by e-mail (one mail per group) before next course:
# * complete the code with comments
# * quick report on what's going one, experimental results etc.
#
# If you don't want to use the notebook, send me the python code + a PDF with plots and answers.
#
#
# # Neural network: first experiments with a linear model
#
# In this first lab exercise we will code a neural network using numpy, without a neural network library.
# Next week, the lab exercise will be to extend this program with hidden layers and activation functions.
#
# The task is digit recognition: the neural network has to predict which digit in $\{0...9\}$ is written in the input picture. We will use the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset, a standard benchmark in machine learning.
#
# The model is a simple linear  classifier $o = \operatorname{softmax}(Wx + b)$ where:
# * $x$ is an input image that is represented as a column vector, each value being the "color" of a pixel
# * $W$ and $b$ are the parameters of the classifier
# * $\operatorname{softmax}$ transforms the output weight (logits) into probabilities
# * $o$ is column vector that contains the probability of each category
#
# We will train this model via stochastic gradient descent by minimizing the negative log-likelihood of the data:
# $$
#     \hat{W}, \hat{b} = \operatorname{argmin}_{W, b} \sum_{x, y} - \log p(y | x)
# $$
# Although this is a linear model, it classifies raw data without any manual feature extraction step.

# %%
# import libs that we will use
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import math
from sklearn.utils import shuffle
import pickle
import pandas as pd

# To load the data we will use the script of Gaetan Marceau Caron
# You can download it from the course webiste and move it to the same directory that contains this ipynb file
import dataset_loader

# %matplotlib inline

# %% [markdown]
# # 1. Data

# %%
# Download mnist dataset 
if("mnist.pkl.gz" not in os.listdir(".")):
    # !wget http://deeplearning.net/data/mnist/mnist.pkl.gz

# if you have it somewhere else, you can comment the lines above
# and overwrite the path below
mnist_path = "./mnist.pkl.gz"

# %%
# load the 3 splits
train_data, dev_data, test_data = dataset_loader.load_mnist(mnist_path)

X_train = train_data[0]
y_train = train_data[1]

X_dev = dev_data[0]
y_dev = dev_data[1]

X_test = test_data[0]
y_test = test_data[1]

# %% [markdown]
# Each dataset is a list with two elemets:
# * data[0] contains images
# * data[1] contains labels
#
# Data is stored as numpy.ndarray. You can use data[0][i] to retrieve image number i and data[1][i] to retrieve its label.

# %%
print(train_data[0].shape)
print(train_data[1].shape)
# Out:
# (50000, 784)
# (50000,)

# %%
index = 900
label = train_data[1][index]
picture = train_data[0][index]

print("label: %i" % label)
plt.imshow(picture.reshape(28,28), cmap='Greys')
# Out:
# label: 1

# %% [markdown]
# **Question:** What are the characteristics of training data? (number of samples, dimension of input, number of labels)
#
# The documentation of ndarray class is available here: https://docs.scipy.org/doc/numpy/reference/generated/numpy.ndarray.html

# %%
def getDimDataset(data):
    n_training = data[0].shape[0]
    n_feature = data[0].shape[1]
    n_label = data[1].shape[0]
    return n_training, n_feature, n_label

# %%
getDimDataset(train_data)
# Out:
# (50000, 784, 50000)

# %% [markdown]
# # 1. Building functions
#
# We now need to build functions that are required for the neural network.
# $$
#     o = \operatorname{softmax}(Wx + b) \\
#     L(x, y) = -\log p(y | x) = -\log o[y]
# $$
#
# Note that in numpy, operator @ is used for matrix multiplication while * is used for element-wise multiplication.
# The documentation for linear algebra in numpy is available here: https://docs.scipy.org/doc/numpy/reference/routines.linalg.html
#
# The first operation is the affine transformation $v = Wx + b$.
# To compute the gradient, it is often convenient to write the forward pass as $v[i] = b[i] + \sum_j W[i, j] x[j]$.

# %%
# Input:
# - W: projection matrix
# - b: bias
# - x: input features
# Output:
# - vector
def affine_transform(W, b, x):
    v = W @ x + b
    return v

# Input:
# - W: projection matrix
# - b: bias
# - x: input features
# - g: incoming gradient
# Output:
# - g_W: gradient wrt W
# - g_b: gradient wrt b
def backward_affine_transform(W, b, x, g):
    g_W = g.reshape(-1, 1) @ x.reshape(1, -1)
    g_b = g
    return g_W, g_b

# %% [markdown]
# The next cell is a (too simple) test of affine_transform and backward_affine_transform.
# It should run without error if your implementation is correct.

# %%
W = np.asarray([[ 0.63024213,  0.53679375, -0.92079597],
 [-0.1155045,   0.62780356, -0.67961305],
 [ 0.08465286, -0.06561815, -0.39778322],
 [ 0.8242268,   0.58907262, -0.52208052],
 [-0.43894227, -0.56993247,  0.09520727]])
b = np.asarray([ 0.42706842,  0.69636598, -0.85611933, -0.08682553,  0.83160079])
x = np.asarray([-0.32809223, -0.54751413,  0.81949319])

o_gold = np.asarray([-0.82819732, -0.16640748, -1.17394705, -1.10761496,  1.36568213])
g = np.asarray([-0.08938868,  0.44083873, -0.2260743,  -0.96196726, -0.53428805])
g_W_gold = np.asarray([[ 0.02932773,  0.04894156, -0.07325341],
 [-0.14463576, -0.24136543,  0.36126434],
 [ 0.07417322,  0.12377887, -0.18526635],
 [ 0.31561399,  0.52669067, -0.78832562],
 [ 0.17529576,  0.29253025, -0.43784542]])
g_b_gold = np.asarray([-0.08938868,  0.44083873, -0.2260743,  -0.96196726, -0.53428805])


# quick test of the forward pass
o = affine_transform(W, b, x)
if o.shape != o_gold.shape:
    raise RuntimeError("Unexpected output dimension: got %s, expected %s" % (str(o.shape), str(o_gold.shape)))
if not np.allclose(o, o_gold):
    raise RuntimeError("Output of the affine_transform function is incorrect")
    
# quick test if the backward pass
g_W, g_b = backward_affine_transform(W, b, x, g)
if g_W.shape != g_W_gold.shape:
        raise RuntimeError("Unexpected gradient dimension for W: got %s, expected %s" % (str(g_W.shape), str(g_W_gold.shape)))
if g_b.shape != g_b_gold.shape:
        raise RuntimeError("Unexpected gradient dimension for b: got %s, expected %s" % (str(g_b.shape), str(g_b_gold.shape)))
if not np.allclose(g_W, g_W_gold):
    raise RuntimeError("Gradient of W is incorrect")
if not np.allclose(g_b, g_b_gold):
    raise RuntimeError("Gradient of b is incorrect")

# %% [markdown]
# The softmax function:
# $$
#      o = \operatorname{softmax}(w)
# $$
# where $w$ is a vector of logits in $\mathbb R$ and $o$ a vector of probabilities such that:
# $$
#     o[i] = \frac{\exp(w[i])}{\sum_j \exp(w[j])}
# $$
# We do not need to implement the backward for this experiment.

# %%
# Input:
# - x: vector of logits
# Output
# - vector of probabilities
def softmax(x):
    return np.exp(x - np.max(x)) / np.sum(np.exp(x-np.max(x)))

# %% [markdown]
# **WARNING:** is your implementation numerically stable?
#
# The $\exp$ function results in computations that overflows (i.e. results in numbers that cannot be represented with floating point numbers).
# Therefore, it is always convenient to use the following trick to improve stability: https://timvieira.github.io/blog/post/2014/02/11/exp-normalize-trick/

# %%
# Example for testing the numerical stability of softmax
# It should return [1., 0. ,0.], not [nan, 0., 0.]
z = [1000000,1,100]
print(softmax(z))
# Out:
# [1. 0. 0.]

# %% [markdown]
# **Question**: from the result of the cell above, what can you say about the softmax output, even when it is stable?

# %%
# Just too simple test for the softmax function
x = np.asarray([0.92424884, -0.92381088, -0.74666024, -0.87705478, -0.54797015])
y_gold = np.asarray([0.57467369, 0.09053556, 0.10808233, 0.09486917, 0.13183925])

y = softmax(x)
if not np.allclose(y, y_gold):
    raise RuntimeError("Output of the softmax function is incorrect")

# %% [markdown]
# Finally, we build the loss function and its gradient for training the network.
#
# The loss function is the negative log-likelihood defined as:
# $$
#     \mathcal L(x, gold) = -\log \frac{\exp(x[gold])}{\sum_j \exp(x[j])} = -x[gold] + \log \sum_j \exp(x[j])
# $$
# This function is also called the cross-entropy loss (in Pytorch, different names are used dependending if the inputs are probabilities or raw logits).
#
# Similarly to the softmax, we have to rely on the log-sum-exp trick to stabilize the computation: https://timvieira.github.io/blog/post/2014/02/11/exp-normalize-trick/

# %%
# Input:
# - x: vector of logits
# - gold: index of the gold class
# Output:
# - scalare equal to -log(softmax(x)[gold])
def nll(x, gold):
    return -x[gold] + np.max(x) + np.log(np.sum(np.exp(x - np.max(x))))

# Input:
# - x: vector of logits
# - gold: index of the gold class
# - gradient (scalar)
# Output:
# - gradient wrt x
def backward_nll(x, gold, g):
    result = np.exp(x - np.max(x)) / np.sum(np.exp(x - np.max(x)))
    result[gold] = -1 + result[gold]
    return result

# %%
# test
x = np.asarray([-0.13590009, -0.83649656,  0.03130881,  0.42559402,  0.08488182])
y_gold = 1.5695014420179738
g_gold = np.asarray([ 0.17609875,  0.08739591, -0.79185107,  0.30875221,  0.2196042 ])

y = nll(x, 2)
g = backward_nll(x, 2, 1.)

if not np.allclose(y, y_gold):
    raise RuntimeError("Output is incorrect")

if g.shape != g_gold.shape:
        raise RuntimeError("Unexpected gradient dimension: got %s, expected %s" % (str(g.shape), str(g_gold.shape)))
if not np.allclose(g, g_gold):
    raise RuntimeError("Gradient is incorrect")

# %% [markdown]
# The following code test the implementation of the gradient using finite-difference approximation, see: https://timvieira.github.io/blog/post/2017/04/21/how-to-test-gradient-implementations/
#
# Your implementation should pass this test.

# %%
# this is python re-implementation of the test from the Dynet library
# https://github.com/clab/dynet/blob/master/dynet/grad-check.cc

def is_almost_equal(grad, computed_grad):
    #print(grad, computed_grad)
    f = abs(grad - computed_grad)
    m = max(abs(grad), abs(computed_grad))

    if f > 0.01 and m > 0.:
        f /= m

    if f > 0.01 or math.isnan(f):
        return False
    else:
        return True

def check_gradient(function, weights, true_grad, alpha = 1e-3):
    # because input can be of any dimension,
    # we build a view of the underlying data with the .shape(-1) method
    # then we can access any element of the tensor as a elements of a list
    # with a single dimension
    weights_view = weights.reshape(-1)
    true_grad_view = true_grad.reshape(-1)
    for i in range(weights_view.shape[0]):
        old = weights_view[i]

        weights_view[i] = old - alpha
        value_left = function(weights).reshape(-1)

        weights_view[i] = old + alpha
        value_right = function(weights).reshape(-1)

        weights_view[i] = old
        grad = (value_right - value_left) / (2. * alpha)
        
        #print(grad, true_grad)
        if not is_almost_equal(grad, true_grad_view[i]):
            return False

        return True

# %%
# Test the affine transformation

x = np.random.uniform(-1, 1, (5,))
W = np.random.uniform(-1, 1, (3, 5))
b = np.random.uniform(-1, 1, (3,))

for i in range(3):
    y = affine_transform(W, b, x)
    g = np.zeros_like(y)
    g[i] = 1.
    g_W, _ = backward_affine_transform(W, b, x, g)
    print(check_gradient(lambda W: affine_transform(W, b, x)[i], W, g_W))
# Out:
# True
# True
# True

# %%
# test the negative likelihood loss

x = np.random.uniform(-1, 1, (5,))

for gold in range(5):
    y = nll(x, gold)
    g_y = backward_nll(x, gold, 1.)

    print(check_gradient(lambda x: nll(x, gold), x, g_y))
# Out:
# True
# True
# True
# True
# True

# %% [markdown]
# # 2. Parameter initialization
#
# We are now going to build the function that will be used to initialize the parameters of the neural network before training.
# Note that for parameter initialization you must use **in-place** operations:

# %%
# create a random ndarray
a = np.random.uniform(-1, 1, (5,))

# this does not change the data of the ndarray created above!
# it creates a new ndarray and replace the reference stored in a
a = np.zeros((5, ))

# this will change the underlying data of the ndarray that a points to
a[:] = 0

# similarly, this creates a new array and change the object pointed by a
a = a + 1

# while this change the underlying data of a
a += 1

# %% [markdown]
# For an affine transformation, it is common to:
# * initialize the bias to 0
# * initialize the projection matrix with Glorot initialization (also known as Xavier initialization)
#
# The formula for Glorot initialization can be found in equation 16 (page 5) of the original paper: http://proceedings.mlr.press/v9/glorot10a/glorot10a.pdf

# %%
def zero_init(dim):
    return np.zeros(dim)

def glorot_init(m, n):
    init_value = np.sqrt(6 / (m + n))
    return np.random.uniform(-init_value, init_value, (m, n))

# %% [markdown]
# # 3. Building and training the neural network
#
# In our simple example, creating the neural network is simply instantiating the parameters $W$ and $b$.
# They must be ndarray object with the correct dimensions.

# %%
def create_parameters(dim_input, dim_output):
    W = glorot_init(dim_output, dim_input)
    b = zero_init(dim_output)
    
    return W, b

# %% [markdown]
# The recent success of deep learning is (partly) due to the ability to train very big neural networks.
# However, researchers became interested in building small neural networks to improve computational efficiency and memory usage.
# Therefore, we often want to compare neural networks by their number of parameters, i.e. the size of the memory required to store the parameters.

# %%
def print_n_parameters(W, b):
    n = W.size + b.size
    print("Number of parameters: %i" % (n))

# %% [markdown]
# We can now create the neural network and print its number of parameters:

# %%
dim_input = train_data[0].shape[1]
dim_output = 10

W, b = create_parameters(dim_input, dim_output)
print_n_parameters(W, b)
# Out:
# Number of parameters: 7850

# %% [markdown]
# Finally, the training loop!
#
# The training loop should be structured as follows:
# * we do **epochs** over the data, i.e. one epoch is one loop over the dataset
# * at each epoch, we first loop over the data and update the network parameters with respect to the loss gradient
# * at the end of each epoch, we evaluate the network on the dev dataset
# * after all epochs are done, we evaluate our network on the test dataset and compare its performance with the performance on dev
#
# During training, it is useful to print the following information:
# * the mean loss over the epoch: it should be decreasing!
# * the accuracy on the dev set: it should be increasing!
# * the accuracy on the train set: it shoud be increasing!
#
# If you observe a decreasing loss (+increasing accuracy on test data) but decreasing accuracy on dev data, your network is overfitting!
#
# Once you have build **and tested** this a simple training loop, you should introduce the following improvements:
# * instead of evaluating on dev after each loop on the training data, you can also evaluate on dev n times per epoch
# * shuffle the data before each epoch
# * instead of memorizing the parameters of the last epoch only, you should have a copy of the parameters that produced the best value on dev data during training and evaluate on test with those instead of the parameters after the last epoch
# * learning rate decay: if you do not observe improvement on dev, you can try to reduce the step size
#
# After you conducted (successful?) experiments, you should write a report with results.

# %%
def model_validation(X, y, model_params):
    W = model_params[0]
    b = model_params[1]
    
    tot_loss = 0.
    accurancy = 0
    
    size = X.shape[0]
    
    for i in range(size):
        x = X[i]
        label = y[i]
        
        # Prediction
        net_out = affine_transform(W, b, x)
        loss = nll(net_out, label)

        prediction = np.argmax(net_out)
        
        tot_loss += loss
        accurancy += 1 if prediction == label else 0
    
    return accurancy/size, tot_loss/size

# %%
def stats_backup(filename, *argv):
    with open(filename, "a") as f:
        line = [str(x) for x in argv]
        f.write(','.join(line) + "\n")

# %%
def weights_backup(params_filename, model_params):
    with open(params_filename, "wb") as f:
        pickle.dump(model_params, f)

# %%
def write_description(filename, description):
    with open(filename, "w") as f:
        f.write(description +"\n")

# %% [markdown]
# # Model 1:
#
# - Static Step Size of 0.01
# - 50 Epochs
# - We shuffle the training data at the start of each epoch
# - We save the params with best accuracy on dev set

# %%
# Init of backup files
filename = "train_1.csv"
params_filename = "train_1.pkl"
write_description("train_1.txt", "Static Step Size 0.01")

with open(filename, "w") as f:
    f.write("Avg Train Loss,Avg Dev Loss,Train Accurancy,Dev Accurancy\n")

# %%
n_epochs = 50 # number of epochs
step = 0.01 # step size for gradient updates

train_size = X_train.shape[0]

W, b = create_parameters(dim_input, dim_output)

best_acc = sys.float_info.min

for epoch in range(n_epochs):
    X_train, y_train = shuffle(X_train, y_train)
    
    tot_loss = 0.
    train_accurancy = 0
    
    for i in range(train_size):
        x = X_train[i]
        label = y_train[i]
        
        # Prediction
        net_out = affine_transform(W, b, x)
        loss = nll(net_out, label)
        
        prediction = np.argmax(net_out)
        
        # Backpropagation
        gradient_loss = backward_nll(net_out, label, 1.)
        gradient_w, gradient_b = backward_affine_transform(W, b, x, gradient_loss)

        W -= step*gradient_w
        b -= step*gradient_b
        
        # Training statistics
        tot_loss += loss
        train_accurancy += 1 if prediction == label else 0
    
    dev_accurancy, dev_avg_loss = model_validation(X_dev, y_dev, [W,b])
    
    if dev_accurancy > best_acc: 
        best_acc = dev_accurancy
        W_best = W
        b_best = b
    
    print("Epoch: {:d}/{:d}".format(epoch+1,n_epochs))
    print ("Train Avg loss:", tot_loss/train_size, "\tDev Avg Loss:", dev_avg_loss)
    print ("Train Accurancy:", train_accurancy/train_size, "\t\tDev Accurancy:", dev_accurancy)
    print()
    stats_backup(filename, tot_loss/train_size, dev_avg_loss, train_accurancy/train_size, dev_accurancy)
    weights_backup(params_filename, [W_best,b_best])
# Out:
# Epoch: 1/50
# Train Avg loss: 0.3761573049211195 	Dev Avg Loss: 0.3240456449723892
# Train Accurancy: 0.89186 		Dev Accurancy: 0.9069
#
# Epoch: 2/50
# Train Avg loss: 0.3100037150713513 	Dev Avg Loss: 0.28932827995922283
# Train Accurancy: 0.91136 		Dev Accurancy: 0.9187
#
# Epoch: 3/50
# Train Avg loss: 0.29683938147626615 	Dev Avg Loss: 0.27687773803006893
# Train Accurancy: 0.91478 		Dev Accurancy: 0.9246
#
# Epoch: 4/50
# Train Avg loss: 0.2912052109981596 	Dev Avg Loss: 0.2770353120855404
# Train Accurancy: 0.9188 		Dev Accurancy: 0.9237
#
# Epoch: 5/50
# Train Avg loss: 0.2852369401567828 	Dev Avg Loss: 0.270262785560021
# Train Accurancy: 0.91844 		Dev Accurancy: 0.9259
#
# Epoch: 6/50
# Train Avg loss: 0.2818661379954127 	Dev Avg Loss: 0.27931753446885527
# Train Accurancy: 0.92092 		Dev Accurancy: 0.9208
#
# Epoch: 7/50
# Train Avg loss: 0.27884064833711997 	Dev Avg Loss: 0.27542766274713765
# Train Accurancy: 0.92186 		Dev Accurancy: 0.9252
#
# Epoch: 8/50
# Train Avg loss: 0.276131131055249 	Dev Avg Loss: 0.27788915521074226
# Train Accurancy: 0.92204 		Dev Accurancy: 0.921
#
# Epoch: 9/50
# Train Avg loss: 0.2743457537811239 	Dev Avg Loss: 0.2717464311209361
# Train Accurancy: 0.92202 		Dev Accurancy: 0.9272
#
# Epoch: 10/50
# Train Avg loss: 0.2722648921019315 	Dev Avg Loss: 0.2876552218435375
# Train Accurancy: 0.92322 		Dev Accurancy: 0.9195
#
# Epoch: 11/50
# Train Avg loss: 0.27099260016068744 	Dev Avg Loss: 0.27664762151215755
# Train Accurancy: 0.92416 		Dev Accurancy: 0.9221
#
# Epoch: 12/50
# Train Avg loss: 0.269496634986369 	Dev Avg Loss: 0.2736017936070279
# Train Accurancy: 0.92476 		Dev Accurancy: 0.9246
#
# Epoch: 13/50
# Train Avg loss: 0.2682897345364986 	Dev Avg Loss: 0.285829407251425
# Train Accurancy: 0.92466 		Dev Accurancy: 0.9232
#
# Epoch: 14/50
# Train Avg loss: 0.2665505049551717 	Dev Avg Loss: 0.28633184898650205
# Train Accurancy: 0.92478 		Dev Accurancy: 0.9203
#
# Epoch: 15/50
figure, axs = plt.subplots(1, 2, figsize=(19,9))
figure.suptitle(description, fontsize=20)

df.plot(kind="line", x="Epoch", y="Avg Train Loss", color="blue", ax=axs[0])
df.plot(kind="line", x="Epoch", y="Avg Dev Loss", color="red", ax=axs[0])

df.plot(kind="line", x="Epoch", y="Train Accurancy", color="blue", ax=axs[1])
df.plot(kind="line", x="Epoch", y="Dev Accurancy", color="red", ax=axs[1])

plt.savefig('train_1.png')

# %% [markdown]
# # Model 2:
#
# - Decaying Step Size
# - 50 Epochs
# - We shuffle the training data at the start of each epoch
# - We save the params with best accuracy on dev set

# %%
# Init of backup files
filename = "train_2.csv"
params_filename = "train_2.pkl"
write_description("train_2.txt", "Dynamic Step Size between [0.01,0.00001]")

with open(filename, "w") as f:
    f.write("Avg Train Loss,Avg Dev Loss,Train Accurancy,Dev Accurancy\n")

# %%
n_epochs = 50 # number of epochs

train_size = X_train.shape[0]

W, b = create_parameters(dim_input, dim_output)

best_acc = sys.float_info.min

for epoch in range(n_epochs):
    if epoch <= 4: step = 0.01
    elif (epoch >= 5) and (epoch <= 14): step = 0.001
    elif (epoch >= 15) and (epoch <= 24): step = 0.0001
    elif (epoch >= 25) and (epoch <= 49): step = 0.00001
        
    X_train, y_train = shuffle(X_train, y_train)
    
    tot_loss = 0.
    train_accurancy = 0
    
    for i in range(train_size):
        x = X_train[i]
        label = y_train[i]
        
        # Prediction
        net_out = affine_transform(W, b, x)
        loss = nll(net_out, label)
        
        prediction = np.argmax(net_out)
        
        # Backpropagation
        gradient_loss = backward_nll(net_out, label, 1.)
        gradient_w, gradient_b = backward_affine_transform(W, b, x, gradient_loss)

        W -= step*gradient_w
        b -= step*gradient_b
        
        # Training statistics
        tot_loss += loss
        train_accurancy += 1 if prediction == label else 0
    
    dev_accurancy, dev_avg_loss = model_validation(X_dev, y_dev, [W,b])
    
    if dev_accurancy > best_acc: 
        best_acc = dev_accurancy
        W_best = W
        b_best = b
    
    print("Epoch: {:d}/{:d}".format(epoch+1,n_epochs))
    print ("Train Avg loss:", tot_loss/train_size, "\tDev Avg Loss:", dev_avg_loss)
    print ("Train Accurancy:", train_accurancy/train_size, "\t\tDev Accurancy:", dev_accurancy)
    print()
    stats_backup(filename, tot_loss/train_size, dev_avg_loss, train_accurancy/train_size, dev_accurancy)
    weights_backup(params_filename, [W_best,b_best])
# Out:
# Epoch: 1/50
# Train Avg loss: 0.37780228942986976 	Dev Avg Loss: 0.293224819443043
# Train Accurancy: 0.89104 		Dev Accurancy: 0.9173
#
# Epoch: 2/50
# Train Avg loss: 0.3095494983910812 	Dev Avg Loss: 0.2747192790162199
# Train Accurancy: 0.91166 		Dev Accurancy: 0.9224
#
# Epoch: 3/50
# Train Avg loss: 0.29747106873378665 	Dev Avg Loss: 0.277273341703922
# Train Accurancy: 0.91558 		Dev Accurancy: 0.9245
#
# Epoch: 4/50
# Train Avg loss: 0.29052345951768105 	Dev Avg Loss: 0.28139505571537027
# Train Accurancy: 0.91764 		Dev Accurancy: 0.9222
#
# Epoch: 5/50
#
# Epoch: 42/50
# Train Avg loss: 0.24918378785437983 	Dev Avg Loss: 0.2576803531840067
# Train Accurancy: 0.9306 		Dev Accurancy: 0.9294
#
# Epoch: 43/50
# Train Avg loss: 0.24918152895811893 	Dev Avg Loss: 0.25768097036248316
# Train Accurancy: 0.93074 		Dev Accurancy: 0.9294
#
# Epoch: 44/50
# Train Avg loss: 0.24917764781964644 	Dev Avg Loss: 0.2576812129656581
# Train Accurancy: 0.93068 		Dev Accurancy: 0.9293
#
# Epoch: 45/50
# Train Avg loss: 0.24917569468137893 	Dev Avg Loss: 0.25768113365286904
# Train Accurancy: 0.93068 		Dev Accurancy: 0.9294
#
# Epoch: 46/50
# Train Avg loss: 0.249172502016039 	Dev Avg Loss: 0.2576786556436349
# Train Accurancy: 0.93062 		Dev Accurancy: 0.9294
#
# Epoch: 47/50
# Train Avg loss: 0.24917040568833643 	Dev Avg Loss: 0.25767794329541177
# Train Accurancy: 0.9306 		Dev Accurancy: 0.9293
#
# Epoch: 48/50
# Train Avg loss: 0.2491672573469285 	Dev Avg Loss: 0.25767758394601525
# Train Accurancy: 0.93072 		Dev Accurancy: 0.9294
#
# Epoch: 49/50
# Train Avg loss: 0.24916448876125527 	Dev Avg Loss: 0.2576759018221768
# Train Accurancy: 0.93076 		Dev Accurancy: 0.9294
#
# Epoch: 50/50
# Train Avg loss: 0.24916182561294137 	Dev Avg Loss: 0.25767601177971405
# Train Accurancy: 0.93078 		Dev Accurancy: 0.9294

# %%
# Plot the training suite
with open ("train_2.txt", "r") as f:
    description = f.read()

df = pd.read_csv("train_2.csv")
df['Epoch'] = df.index

figure, axs = plt.subplots(1, 2, figsize=(19,9))
figure.suptitle(description, fontsize=20)

df.plot(kind="line", x="Epoch", y="Avg Train Loss", color="blue", ax=axs[0])
df.plot(kind="line", x="Epoch", y="Avg Dev Loss", color="red", ax=axs[0])

df.plot(kind="line", x="Epoch", y="Train Accurancy", color="blue", ax=axs[1])
df.plot(kind="line", x="Epoch", y="Dev Accurancy", color="red", ax=axs[1])

plt.savefig('train_2.png')

# %% [markdown]
# # Model 3
#
# - Updating parameters after every epoch i.e. substracting the average gradient
# - Learning rate: 0.1
# - Epochs: 2000
# - We shuffle the training data at the start of each epoch

# %%
# Init of backup files
filename = "train_3.csv"
params_filename = "train_3.pkl"
write_description("train_3.txt", "Static Step Size 0.1")

with open(filename, "w") as f:
    f.write("Avg Train Loss,Avg Dev Loss,Train Accurancy,Dev Accurancy\n")

# %%
n_epochs = 2000 # number of epochs
step = 0.1 # step size for gradient updates

train_size = X_train.shape[0]

W, b = create_parameters(dim_input, dim_output)

best_acc = sys.float_info.min

for epoch in range(n_epochs):
    X_train, y_train = shuffle(X_train, y_train)
    
    tot_loss = 0.
    train_accurancy = 0

    avg_gradient_w = 0.
    avg_gradient_b = 0.
    
    for i in range(train_size):
        x = X_train[i]
        label = y_train[i]
        
        # Prediction
        net_out = affine_transform(W, b, x)
        loss = nll(net_out, label)
        
        prediction = np.argmax(net_out)
        
        # Backpropagation
        gradient_loss = backward_nll(net_out, label, 1.)
        gradient_w, gradient_b = backward_affine_transform(W, b, x, gradient_loss)

        avg_gradient_w += gradient_w
        avg_gradient_b += gradient_b
        
        # Training statistics
        tot_loss += loss
        train_accurancy += 1 if prediction == label else 0

    avg_gradient_w /= train_size
    avg_gradient_b /= train_size
    
    W -= step*avg_gradient_w
    b -= step*avg_gradient_b
    
    dev_accurancy, dev_avg_loss = model_validation(X_dev, y_dev, [W,b])
    
    if dev_accurancy > best_acc: 
        best_acc = dev_accurancy
        W_best = W
        b_best = b
    
    print("Epoch: {:d}/{:d}".format(epoch+1,n_epochs))
    print ("Train Avg loss:", tot_loss/train_size, "\tDev Avg Loss:", dev_avg_loss)
    print ("Train Accurancy:", train_accurancy/train_size, "\t\tDev Accurancy:", dev_accurancy)
    print()
    stats_backup(filename, tot_loss/train_size, dev_avg_loss, train_accurancy/train_size, dev_accurancy)
    weights_backup(params_filename, [W_best,b_best])
# Out:
# Epoch: 1/2000
# Train Avg loss: 2.4741710299150688 	Dev Avg Loss: 2.333613431871317
# Train Accurancy: 0.05994 		Dev Accurancy: 0.1034
#
# Epoch: 2/2000
# Train Avg loss: 2.334954676200328 	Dev Avg Loss: 2.2167161607821613
# Train Accurancy: 0.10178 		Dev Accurancy: 0.1795
#
# Epoch: 3/2000
# Train Avg loss: 2.222036147917147 	Dev Avg Loss: 2.1143293542569124
# Train Accurancy: 0.18038 		Dev Accurancy: 0.2813
#
# Epoch: 4/2000
# Train Avg loss: 2.1230495616598146 	Dev Avg Loss: 2.0216921202357225
# Train Accurancy: 0.27384 		Dev Accurancy: 0.3811
#
# Epoch: 5/2000
# Train Avg loss: 2.033361716265063 	Dev Avg Loss: 1.9367009845765475
# Train Accurancy: 0.36448 		Dev Accurancy: 0.4642
#
# Epoch: 6/2000
# Train Avg loss: 1.950979647072265 	Dev Avg Loss: 1.8582917720859633
# Train Accurancy: 0.442 		Dev Accurancy: 0.5239
#
# Epoch: 7/2000
# Train Avg loss: 1.874921935515879 	Dev Avg Loss: 1.785802448671486
# Train Accurancy: 0.50224 		Dev Accurancy: 0.5702
#
# Epoch: 8/2000
# Train Avg loss: 1.8045836611274146 	Dev Avg Loss: 1.7187256694670814
# Train Accurancy: 0.54944 		Dev Accurancy: 0.6099
#
# Epoch: 9/2000
# Train Avg loss: 1.7394956929063514 	Dev Avg Loss: 1.6566188652928868
# Train Accurancy: 0.58648 		Dev Accurancy: 0.6371
#
# Epoch: 10/2000
# Train Avg loss: 1.6792410512153997 	Dev Avg Loss: 1.5990748287560865
# Train Accurancy: 0.6152 		Dev Accurancy: 0.6615
#
# Epoch: 11/2000
# Train Avg loss: 1.6234300157644372 	Dev Avg Loss: 1.545713735196114
# Train Accurancy: 0.63964 		Dev Accurancy: 0.6842
#
# Epoch: 12/2000
# Train Avg loss: 1.5716951195739577 	Dev Avg Loss: 1.4961817745168557
# Train Accurancy: 0.6606 		Dev Accurancy: 0.701
#
# Epoch: 13/2000
# Epoch: 122/2000
# Train Avg loss: 0.5889482304039682 	Dev Avg Loss: 0.5379109217633595
# Train Accurancy: 0.8573 		Dev Accurancy: 0.8747
#
# Epoch: 123/2000
# Train Avg loss: 0.5873146633873246 	Dev Avg Loss: 0.5363432801867022
# Train Accurancy: 0.85756 		Dev Accurancy: 0.8751
#
# Epoch: 124/2000
# Train Avg loss: 0.5857031313671426 	Dev Avg Loss: 0.5347974622549632
# Train Accurancy: 0.85786 		Dev Accurancy: 0.8754
#
# Epoch: 125/2000
# Train Avg loss: 0.5841131580494704 	Dev Avg Loss: 0.5332729913103064
# Train Accurancy: 0.85812 		Dev Accurancy: 0.8756
#
# Epoch: 126/2000
# Train Avg loss: 0.5825442810997725 	Dev Avg Loss: 0.531769404705311
# Train Accurancy: 0.8585 		Dev Accurancy: 0.8757
#
# Epoch: 127/2000
# Train Avg loss: 0.5809960516298849 	Dev Avg Loss: 0.5302862532888825
# Train Accurancy: 0.85866 		Dev Accurancy: 0.8759
#
# Epoch: 128/2000
# Train Avg loss: 0.5794680337077855 	Dev Avg Loss: 0.5288231009147023
# Train Accurancy: 0.85896 		Dev Accurancy: 0.8759
#
# Epoch: 129/2000
# Train Avg loss: 0.5779598038885899 	Dev Avg Loss: 0.5273795239709973
# Train Accurancy: 0.85912 		Dev Accurancy: 0.8761
#
# Epoch: 130/2000
# Train Avg loss: 0.5764709507659255 	Dev Avg Loss: 0.5259551109306901
# Train Accurancy: 0.85948 		Dev Accurancy: 0.8762
#
# Epoch: 131/2000
# Train Avg loss: 0.5750010745426346 	Dev Avg Loss: 0.5245494619207723
# Train Accurancy: 0.85966 		Dev Accurancy: 0.8766
#
# Epoch: 132/2000
# Train Avg loss: 0.5735497866198535 	Dev Avg Loss: 0.5231621883100078
# Train Accurancy: 0.86006 		Dev Accurancy: 0.877
#
# Epoch: 133/2000
# Train Avg loss: 0.5721167092033949 	Dev Avg Loss: 0.5217929123141213
# Train Accurancy: 0.86024 		Dev Accurancy: 0.8772
#
# Epoch: 134/2000
# Train Avg loss: 0.5707014749268589 	Dev Avg Loss: 0.5204412666174375
# Train Accurancy: 0.86044 		Dev Accurancy: 0.8773
#
# Epoch: 135/2000
# Train Avg loss: 0.5693037264904226 	Dev Avg Loss: 0.5191068940104144
# Train Accurancy: 0.86086 		Dev Accurancy: 0.8774
#
# Epoch: 136/2000
# Train Avg loss: 0.567923116314602 	Dev Avg Loss: 0.5177894470420689
# Train Accurancy: 0.86122 		Dev Accurancy: 0.8779
#
# Epoch: 137/2000
# Train Avg loss: 0.566559306208341 	Dev Avg Loss: 0.5164885876867422
# Train Accurancy: 0.86144 		Dev Accurancy: 0.8778
#
# Epoch: 138/2000
# Train Avg loss: 0.5652119670506658 	Dev Avg Loss: 0.515203987024474
# Train Accurancy: 0.86168 		Dev Accurancy: 0.8781
#
# Epoch: 139/2000
# Train Avg loss: 0.5638807784852984 	Dev Avg Loss: 0.513935324934252
# Train Accurancy: 0.86202 		Dev Accurancy: 0.8782
#
# Epoch: 140/2000
#
# Epoch: 267/2000
# Train Avg loss: 0.4659781083258537 	Dev Avg Loss: 0.42252823254797095
# Train Accurancy: 0.8783 		Dev Accurancy: 0.8934
#
# Epoch: 268/2000
# Train Avg loss: 0.4655252555203741 	Dev Avg Loss: 0.4221164890995826
# Train Accurancy: 0.87842 		Dev Accurancy: 0.8933
#
# Epoch: 269/2000
# Train Avg loss: 0.4650751121409399 	Dev Avg Loss: 0.42170733593648285
# Train Accurancy: 0.87854 		Dev Accurancy: 0.8935
#
# Epoch: 270/2000
# Train Avg loss: 0.4646276514030983 	Dev Avg Loss: 0.4213007468541932
# Train Accurancy: 0.87862 		Dev Accurancy: 0.8934
#
# Epoch: 271/2000
# Train Avg loss: 0.4641828468884492 	Dev Avg Loss: 0.4208966960105975
# Train Accurancy: 0.87866 		Dev Accurancy: 0.8935
#
# Epoch: 272/2000
# Train Avg loss: 0.4637406725382425 	Dev Avg Loss: 0.420495157919588
# Train Accurancy: 0.87874 		Dev Accurancy: 0.8935
#
# Epoch: 273/2000
# Train Avg loss: 0.4633011026471855 	Dev Avg Loss: 0.4200961074448873
# Train Accurancy: 0.8788 		Dev Accurancy: 0.8935
#
# Epoch: 274/2000
# Train Avg loss: 0.4628641118573771 	Dev Avg Loss: 0.4196995197939589
# Train Accurancy: 0.87896 		Dev Accurancy: 0.8934
#
# Epoch: 275/2000
# Train Avg loss: 0.4624296751522931 	Dev Avg Loss: 0.419305370512076
# Train Accurancy: 0.87908 		Dev Accurancy: 0.8934
#
# Epoch: 276/2000
# Train Avg loss: 0.46199776785099267 	Dev Avg Loss: 0.41891363547649124
# Train Accurancy: 0.87914 		Dev Accurancy: 0.8937
#
# Epoch: 277/2000
# Train Avg loss: 0.46156836560236914 	Dev Avg Loss: 0.41852429089075915
# Train Accurancy: 0.87934 		Dev Accurancy: 0.8938
#
# Epoch: 278/2000
# Train Avg loss: 0.46114144437955923 	Dev Avg Loss: 0.4181373132791301
# Train Accurancy: 0.87942 		Dev Accurancy: 0.8939
#
# Epoch: 279/2000
# Train Avg loss: 0.4607169804744845 	Dev Avg Loss: 0.4177526794811015
# Train Accurancy: 0.87946 		Dev Accurancy: 0.8939
#
# Epoch: 280/2000
# Train Avg loss: 0.46029495049239266 	Dev Avg Loss: 0.41737036664606286
# Train Accurancy: 0.87958 		Dev Accurancy: 0.894
#
# Epoch: 281/2000
# Train Avg loss: 0.45987533134671305 	Dev Avg Loss: 0.41699035222804076
# Train Accurancy: 0.87956 		Dev Accurancy: 0.8941
#
# Epoch: 282/2000
# Train Avg loss: 0.45945810025379485 	Dev Avg Loss: 0.4166126139805854
# Train Accurancy: 0.87966 		Dev Accurancy: 0.8944
#
# Epoch: 283/2000
# Train Avg loss: 0.4590432347279162 	Dev Avg Loss: 0.4162371299517109
# Train Accurancy: 0.87974 		Dev Accurancy: 0.8946
#
# Epoch: 284/2000
# Train Avg loss: 0.4586307125763002 	Dev Avg Loss: 0.41586387847899375
# Train Accurancy: 0.87982 		Dev Accurancy: 0.8948
#
# ...
#
# Epoch: 1884/2000
# Train Avg loss: 0.3215253656209925 	Dev Avg Loss: 0.3001422116266761
# Train Accurancy: 0.91028 		Dev Accurancy: 0.9164
#
# Epoch: 1885/2000
# Train Avg loss: 0.3215024266231737 	Dev Avg Loss: 0.300124665327142
# Train Accurancy: 0.91028 		Dev Accurancy: 0.9164
#
# Epoch: 1886/2000
# Train Avg loss: 0.3214795055047314 	Dev Avg Loss: 0.30010713360106034
# Train Accurancy: 0.91028 		Dev Accurancy: 0.9164
#
# Epoch: 1887/2000
# Train Avg loss: 0.3214566022420534 	Dev Avg Loss: 0.30008961642869103
# Train Accurancy: 0.9103 		Dev Accurancy: 0.9164
#
# Epoch: 1888/2000
# Train Avg loss: 0.32143371681157534 	Dev Avg Loss: 0.30007211379034177
# Train Accurancy: 0.9103 		Dev Accurancy: 0.9164
#
# Epoch: 1889/2000
# Train Avg loss: 0.32141084918977064 	Dev Avg Loss: 0.3000546256663497
# Train Accurancy: 0.91034 		Dev Accurancy: 0.9164
#
# Epoch: 1890/2000
# Train Avg loss: 0.32138799935316853 	Dev Avg Loss: 0.30003715203709463
# Train Accurancy: 0.91034 		Dev Accurancy: 0.9164
#
# Epoch: 1891/2000
# Train Avg loss: 0.3213651672783308 	Dev Avg Loss: 0.30001969288298347
# Train Accurancy: 0.91034 		Dev Accurancy: 0.9164
#
# Epoch: 1892/2000
# Train Avg loss: 0.3213423529418775 	Dev Avg Loss: 0.3000022481844747
# Train Accurancy: 0.91036 		Dev Accurancy: 0.9164
#
# Epoch: 1893/2000
# Train Avg loss: 0.32131955632044756 	Dev Avg Loss: 0.2999848179220555
# Train Accurancy: 0.91034 		Dev Accurancy: 0.9164
#
# Epoch: 1894/2000
# Train Avg loss: 0.32129677739074114 	Dev Avg Loss: 0.2999674020762502
# Train Accurancy: 0.91034 		Dev Accurancy: 0.9164
#
# Epoch: 1895/2000
# Train Avg loss: 0.3212740161295009 	Dev Avg Loss: 0.29995000062761995
# Train Accurancy: 0.91034 		Dev Accurancy: 0.9165
#
# Epoch: 1896/2000
# Train Avg loss: 0.3212512725135063 	Dev Avg Loss: 0.2999326135567652
# Train Accurancy: 0.91038 		Dev Accurancy: 0.9164
#
# Epoch: 1897/2000
# Train Avg loss: 0.32122854651957994 	Dev Avg Loss: 0.2999152408443174
# Train Accurancy: 0.91038 		Dev Accurancy: 0.9164
#
# Epoch: 1898/2000
# Train Avg loss: 0.3212058381245948 	Dev Avg Loss: 0.2998978824709517
# Train Accurancy: 0.91038 		Dev Accurancy: 0.9164
#
# Epoch: 1899/2000
# Train Avg loss: 0.3211831473054624 	Dev Avg Loss: 0.29988053841737844
# Train Accurancy: 0.91042 		Dev Accurancy: 0.9164
#
# Epoch: 1900/2000
# Train Avg loss: 0.3211604740391249 	Dev Avg Loss: 0.29986320866433736
# Train Accurancy: 0.91042 		Dev Accurancy: 0.9164
#
# Epoch: 1901/2000
# Train Avg loss: 0.321137818302588 	Dev Avg Loss: 0.2998458931926115
# Train Accurancy: 0.91042 		Dev Accurancy: 0.9164
#
# Epoch: 1902/2000
# Train Avg loss: 0.3211151800728821 	Dev Avg Loss: 0.2998285919830198
# Train Accurancy: 0.91042 		Dev Accurancy: 0.9164
#
# Epoch: 1903/2000
# Train Avg loss: 0.3210925593270991 	Dev Avg Loss: 0.2998113050164106
# Train Accurancy: 0.91044 		Dev Accurancy: 0.9164
#
# Epoch: 1904/2000
# Train Avg loss: 0.3210699560423542 	Dev Avg Loss: 0.299794032273677
# Train Accurancy: 0.91046 		Dev Accurancy: 0.9164
#
# Epoch: 1905/2000
# Train Avg loss: 0.3210473701958065 	Dev Avg Loss: 0.2997767737357412
# Train Accurancy: 0.91046 		Dev Accurancy: 0.9164
#
# Epoch: 1906/2000
# Train Avg loss: 0.32102480176467035 	Dev Avg Loss: 0.29975952938356515
# Train Accurancy: 0.91052 		Dev Accurancy: 0.9164
#
# Epoch: 1907/2000
# Train Avg loss: 0.3210022507261887 	Dev Avg Loss: 0.2997422991981449
# Train Accurancy: 0.91052 		Dev Accurancy: 0.9164
#
# Epoch: 1908/2000
# Train Avg loss: 0.320979717057654 	Dev Avg Loss: 0.299725083160512
# Train Accurancy: 0.9105 		Dev Accurancy: 0.9164
#
# Epoch: 1909/2000
# Train Avg loss: 0.3209572007364012 	Dev Avg Loss: 0.2997078812517364
# Train Accurancy: 0.9105 		Dev Accurancy: 0.9164
#
# Epoch: 1910/2000
# Train Avg loss: 0.3209347017397999 	Dev Avg Loss: 0.29969069345291693
# Train Accurancy: 0.9105 		Dev Accurancy: 0.9164
#
# Epoch: 1911/2000
# Train Avg loss: 0.3209122200452634 	Dev Avg Loss: 0.2996735197451981
# Train Accurancy: 0.91052 		Dev Accurancy: 0.9164
#
# Epoch: 1912/2000
# Train Avg loss: 0.3208897556302559 	Dev Avg Loss: 0.2996563601097476
# Train Accurancy: 0.91052 		Dev Accurancy: 0.9165
#
# Epoch: 1913/2000
# Train Avg loss: 0.3208673084722575 	Dev Avg Loss: 0.29963921452777836
# Train Accurancy: 0.91052 		Dev Accurancy: 0.9167
#
# Epoch: 1914/2000
# Train Avg loss: 0.3208448785488295 	Dev Avg Loss: 0.2996220829805329
# Train Accurancy: 0.91056 		Dev Accurancy: 0.9167
#
# Epoch: 1915/2000
# Train Avg loss: 0.3208224658375353 	Dev Avg Loss: 0.2996049654492908
# Train Accurancy: 0.91058 		Dev Accurancy: 0.9167
#
# Epoch: 1916/2000
# Train Avg loss: 0.3208000703160067 	Dev Avg Loss: 0.2995878619153672
# Train Accurancy: 0.91058 		Dev Accurancy: 0.9167
#
# Epoch: 1917/2000
# Train Avg loss: 0.32077769196189404 	Dev Avg Loss: 0.2995707723601085
# Train Accurancy: 0.9106 		Dev Accurancy: 0.9167
#
# Epoch: 1918/2000
# Train Avg loss: 0.32075533075290935 	Dev Avg Loss: 0.29955369676490035
# Train Accurancy: 0.9106 		Dev Accurancy: 0.9167
#
# Epoch: 1919/2000
# Train Avg loss: 0.32073298666678524 	Dev Avg Loss: 0.2995366351111599
# Epoch: 1973/2000
# Train Avg loss: 0.3195512321656561 	Dev Avg Loss: 0.2986355071444417
# Train Accurancy: 0.91084 		Dev Accurancy: 0.9167
#
# Epoch: 1974/2000
# Train Avg loss: 0.31952979671328857 	Dev Avg Loss: 0.2986191846369687
# Train Accurancy: 0.91084 		Dev Accurancy: 0.9167
#
# Epoch: 1975/2000
# Train Avg loss: 0.31950837719952013 	Dev Avg Loss: 0.2986028750833077
# Train Accurancy: 0.91084 		Dev Accurancy: 0.9167
#
# Epoch: 1976/2000
# Train Avg loss: 0.3194869736042654 	Dev Avg Loss: 0.29858657846673015
# Train Accurancy: 0.91086 		Dev Accurancy: 0.9167
#
# Epoch: 1977/2000
# Train Avg loss: 0.31946558590747853 	Dev Avg Loss: 0.29857029477052205
# Train Accurancy: 0.91086 		Dev Accurancy: 0.9167
#
# Epoch: 1978/2000
# Train Avg loss: 0.31944421408913476 	Dev Avg Loss: 0.29855402397802033
# Train Accurancy: 0.91086 		Dev Accurancy: 0.9167
#
# Epoch: 1979/2000
# Train Avg loss: 0.31942285812925636 	Dev Avg Loss: 0.2985377660725735
# Train Accurancy: 0.91086 		Dev Accurancy: 0.9167
#
# Epoch: 1980/2000
# Train Avg loss: 0.3194015180079016 	Dev Avg Loss: 0.2985215210375711
# Train Accurancy: 0.91088 		Dev Accurancy: 0.9167
#
# Epoch: 1981/2000
# Train Avg loss: 0.31938019370515164 	Dev Avg Loss: 0.29850528885643063
# Train Accurancy: 0.91088 		Dev Accurancy: 0.9167
#
# Epoch: 1982/2000
# Train Avg loss: 0.3193588852011402 	Dev Avg Loss: 0.29848906951259535
# Train Accurancy: 0.91084 		Dev Accurancy: 0.9167
#
# Epoch: 1983/2000
# Train Avg loss: 0.3193375924760271 	Dev Avg Loss: 0.2984728629895413
# Train Accurancy: 0.91084 		Dev Accurancy: 0.9167
#
# Epoch: 1984/2000
# Train Avg loss: 0.31931631551000084 	Dev Avg Loss: 0.298456669270777
# Train Accurancy: 0.91086 		Dev Accurancy: 0.9167
#
# Epoch: 1985/2000
# Train Avg loss: 0.31929505428329596 	Dev Avg Loss: 0.2984404883398374
# Train Accurancy: 0.91086 		Dev Accurancy: 0.9167
#
# Epoch: 1986/2000
# Train Avg loss: 0.3192738087761735 	Dev Avg Loss: 0.29842432018028814
# Train Accurancy: 0.91086 		Dev Accurancy: 0.9167
#
# Epoch: 1987/2000
# Train Avg loss: 0.31925257896894027 	Dev Avg Loss: 0.2984081647757211
# Train Accurancy: 0.91086 		Dev Accurancy: 0.9167
#
# Epoch: 1988/2000
# Train Avg loss: 0.3192313648419259 	Dev Avg Loss: 0.29839202210976234
# Train Accurancy: 0.91086 		Dev Accurancy: 0.9167
#
# Epoch: 1989/2000
# Train Avg loss: 0.31921016637549 	Dev Avg Loss: 0.29837589216606514
# Train Accurancy: 0.91086 		Dev Accurancy: 0.9167
#
# Epoch: 1990/2000
# Train Avg loss: 0.31918898355005404 	Dev Avg Loss: 0.2983597749283145
# Train Accurancy: 0.91088 		Dev Accurancy: 0.9167
#
# Epoch: 1991/2000
# Train Avg loss: 0.3191678163460453 	Dev Avg Loss: 0.2983436703802181
# Train Accurancy: 0.9109 		Dev Accurancy: 0.9167
#
# Epoch: 1992/2000
# Train Avg loss: 0.319146664743937 	Dev Avg Loss: 0.2983275785055224
# Train Accurancy: 0.91092 		Dev Accurancy: 0.9167
#
# Epoch: 1993/2000
# Train Avg loss: 0.31912552872423794 	Dev Avg Loss: 0.29831149928799083
# Train Accurancy: 0.91092 		Dev Accurancy: 0.9167
#
# Epoch: 1994/2000
# Train Avg loss: 0.3191044082674821 	Dev Avg Loss: 0.298295432711433
# Train Accurancy: 0.91092 		Dev Accurancy: 0.9167
#
# Epoch: 1995/2000
# Train Avg loss: 0.31908330335425716 	Dev Avg Loss: 0.2982793787596682
# Train Accurancy: 0.91094 		Dev Accurancy: 0.9168
#
# Epoch: 1996/2000
# Train Avg loss: 0.31906221396515566 	Dev Avg Loss: 0.29826333741655764
# Train Accurancy: 0.91096 		Dev Accurancy: 0.9168
#
# Epoch: 1997/2000
# Train Avg loss: 0.319041140080831 	Dev Avg Loss: 0.2982473086659911
# Train Accurancy: 0.91098 		Dev Accurancy: 0.9168
#
# Epoch: 1998/2000
# Train Avg loss: 0.3190200816819589 	Dev Avg Loss: 0.29823129249187974
# Train Accurancy: 0.91098 		Dev Accurancy: 0.9168
#
# Epoch: 1999/2000
# Train Avg loss: 0.318999038749248 	Dev Avg Loss: 0.29821528887816773
# Train Accurancy: 0.91096 		Dev Accurancy: 0.9168
#
# Epoch: 2000/2000
# Train Avg loss: 0.31897801126344716 	Dev Avg Loss: 0.29819929780882937
# Train Accurancy: 0.91096 		Dev Accurancy: 0.917

# %%
# Plot the training suite
with open ("train_3.txt", "r") as f:
    description = f.read()

df = pd.read_csv("train_3.csv")
df['Epoch'] = df.index

figure, axs = plt.subplots(1, 2, figsize=(19,9))
figure.suptitle(description, fontsize=20)

df.plot(kind="line", x="Epoch", y="Avg Train Loss", color="blue", ax=axs[0])
df.plot(kind="line", x="Epoch", y="Avg Dev Loss", color="red", ax=axs[0])

df.plot(kind="line", x="Epoch", y="Train Accurancy", color="blue", ax=axs[1])
df.plot(kind="line", x="Epoch", y="Dev Accurancy", color="red", ax=axs[1])

plt.savefig('train_3.png')

# %%
print("Model\tAccurancy\tAvg Loss")

with open("train_1.pkl", "rb") as f:
    model_params = pickle.load(f)

test_acc, test_loss = model_validation(X_test, y_test, model_params)
print ("1", "%.3f"%test_acc, "\t%.3f"%test_loss, sep="\t")

with open("train_2.pkl", "rb") as f:
    model_params = pickle.load(f)

test_acc, test_loss = model_validation(X_test, y_test, model_params)
print ("2", "%.3f"%test_acc, "\t%.3f"%test_loss, sep="\t")

with open("train_3.pkl", "rb") as f:
    model_params = pickle.load(f)

test_acc, test_loss = model_validation(X_test, y_test, model_params)
print ("3", "%.3f"%test_acc, "\t%.3f"%test_loss, sep="\t")
# Out:
# Model	Accurancy	Avg Loss
# 1	0.924		0.293
# 2	0.926		0.268
# 3	0.916		0.305
